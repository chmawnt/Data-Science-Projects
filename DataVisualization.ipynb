# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
df1 = pd.read_csv('/content/sample_data/df1')
df2 = pd.read_csv('/content/sample_data/df2')
df3 = pd.read_csv('/content/sample_data/df3')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
plt.style.use('ggplot')

# %%
df3['a'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
df3['a'].plot.hist(bins=20,alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3['a'].plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df3['a'].plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df3.plot.line(x='b',y='c',figsize=(12,3),lw=1)
# Out:
# <Axes: xlabel='b'>

# %%
df3.plot.scatter(x='a',y='b',c='red',figsize=(12,3),s=50)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df3[['a','b']].plot.box()
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df3['d'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df3['a'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df3['d'].plot.kde(lw=2,ls='--')
# Out:
# <Axes: ylabel='Density'>

# %%
f = plt.figure()
df3.plot.area(ax=f.gca(),alpha=0.4)
plt.legend(loc='center left',bbox_to_anchor=(1.0,0.5))
plt.show()
